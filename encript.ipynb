# %%
import pandas as pd
import hashlib
import re
from cryptography.fernet import Fernet

# %%
file_path = 'Laptop_price.csv'
try:
    df = pd.read_csv(file_path)
except Exception as e:
    print(f"Ошибка загрузки файла: {e}")

# %%
# def check_csv_injection(df):
#     dangerous_chars = ('=', '+', '-', '@')
#     for col in df.select_dtypes(include=['object']).columns:
#         if df[col].astype(str).apply(lambda x: x.startswith(dangerous_chars)).any():
#            print(f"Обнаружены потенциальные CSV-инъекции в столбце {col}")
#         else:
#            print(f"Столбец {col} безопасен.")


def check_csv_injection(df):
    dangerous_chars = ('=', '+', '-', '@')
    results = []
    
    for col in df.select_dtypes(include=['object']).columns:
        pattern = r'\s*[' + ''.join(dangerous_chars) + r']'
        
        if df[col].str.contains(pattern).any():
            results.append(f"Обнаружены потенциальные CSV-инъекции в столбце {col}")
        else:
            results.append(f"Столбец {col} безопасен.")
    
    return results

           
check_csv_injection(df)
# Out:
# ['Столбец Brand безопасен.']

# %%
# def clean_input(value):
#     sql_keywords = ["SELECT", "DROP", "DELETE", "INSERT", "UPDATE", "ALTER", "UNION"]
#     xss_patterns = [r'<script.*?>.*?</script>', r'javascript:.*', r'oneerror.*']

#     for keyword in sql_keywords:
#         if keyword.lower() in value.lower():
#             return "[BLOCKED]"
#     return value
# df = df.map(lambda x: clean_input(str(x)) if isinstance(x, str) else x)

def clean_input(value):
    sql_keywords = ["SELECT", "DROP", "DELETE", "INSERT", "UPDATE", "ALTER", "UNION"]
    xss_patterns = [r'<script.*?>.*?</script>', r'javascript:.*', r'onerror.*']
    sql_comments_pattern = r'--'

    for keyword in sql_keywords:
        if keyword.lower() in value.lower():
            return "[BLOCKED]"

    if re.search(sql_comments_pattern, value):
        return "[BLOCKED]"

    for pattern in xss_patterns:
        if re.search(pattern, value, re.IGNORECASE):
            return "[BLOCKED]"

    return value

df = df.map(lambda x: clean_input(str(x)) if isinstance(x, str) else x)
print("Фильтрация данных завершена")
# Out:
# Фильтрация данных завершена

# %%
def hash_price(price):
    return hashlib.sha256(str(price).encode()).hexdigest()

df['Price_Hashed'] = df['Price'].apply(hash_price)
print("Столбец с хешированными ценами добавлен.")

key = Fernet.generate_key()
cipher = Fernet(key)

def encypt_price(price):
    return cipher.encrypt(str(price).encode()).decode()

def decrypt_price(encrypted_price):
    return cipher.decrypt(encrypted_price.encode()).decode()

def encrypt_ram(ram):
    return cipher.encrypt(str(ram).encode()).decode()

def decrypt_ram(encrypted_ram):
    return cipher.decrypt(encrypted_ram.encode()).decode()

df['Price_Encripted'] = df['Price'].apply(encypt_price)
print("Столбец с зашифрованными ценами добавлен.")

df['RAM_Size_Encrypted'] = df['RAM_Size'].apply(encrypt_ram)
print("Столбец с зашифрованной RAM добавлен.")

output_path = "Laptop_price_secured.csv"
df.to_csv(output_path, index=False)
print(f"Обработанный файл сохранен: {output_path}")
df
# Out:
# Столбец с хешированными ценами добавлен.
# Столбец с зашифрованными ценами добавлен.
# Столбец с зашифрованной RAM добавлен.
# Обработанный файл сохранен: Laptop_price_secured.csv
#       Brand  Processor_Speed  RAM_Size  Storage_Capacity  Screen_Size  \
# 0      Asus         3.830296        16               512    11.185147
# 1      Acer         2.912833         4              1000    11.311372
# 2    Lenovo         3.241627         4               256    11.853023
# 3      Acer         3.806248        16               512    12.280360
# 4      Acer         3.268097        32              1000    14.990877
# ..      ...              ...       ...               ...          ...
# 995      HP         3.343584         4              1000    12.587095
# 996    Dell         2.780555         8               256    12.679356
# 997    Dell         3.200569         4               512    12.666315
# 998    Asus         1.604182         8               256    11.215581
# 999  Lenovo         1.711980         4               256    16.561498
#
#        Weight         Price  \
# 0    2.641094  17395.093065
# 1    3.260012  31607.605919
# 2    2.029061   9291.023542
# 3    4.573865  17436.728334
# 4    4.193472  32917.990718
# ..        ...           ...
# 995  3.162399  31593.668017
# 996  3.750265   9149.521832
# 997  3.392612  16552.404779
# 998  3.857613   9407.473459
# 999  3.440883   8807.696702
#
#                                           Price_Hashed  \
# 0    e33562234b73b4ecad16901885fd503f2c4c20996e22d9...
# 1    80fe437d4a9c57c4038198b7cf32f93b9f957bb705b8e1...
# 2    6254a5a18d60d796eb464283ef38f9417e12885a07742e...
# 3    1f2910923c33a53b30bc7e6eb731307eb2e2366b3811b6...
# 4    f90738a55c90c1e31a4fb6d35f92306ff03a87001a9408...
# ..                                                 ...
# 995  17c0640d518f40efb4621a91128f37dd255a70325fb7d2...
# 996  3c3a320eef285b3076573e44615fc5079327f9afcc65d1...
# 997  fb06ef3c65b464a25611ccefec44f50e50e6d18a835738...
# 998  dbe23db04d9d9d9537f6c5a65cb51b749612b1699857c0...
# 999  59ad2279dd62c7ef24298c94004fa8573c4d3bc25f925b...
#
#                                        Price_Encripted  \
# 0    gAAAAABn0yoBIJ9V3A3JN9kpN0bnJg0-y5_QV8wycdCWcd...
# 1    gAAAAABn0yoBSQB7MgPVRvuy-d194L-XkwFScWUNDpRvsS...
# 2    gAAAAABn0yoBiyB_9I2UDRniQrcKjNEiunSflPI3lF7-zy...
# 3    gAAAAABn0yoBqni0pH0YbmREKWh14zuzY2UC8VYqpx76OF...
# 4    gAAAAABn0yoBgCDJvcv5aEvgfZwAP2omK22ZNG-hN-l9Bn...
# ..                                                 ...
# 995  gAAAAABn0yoBrqWhXg3KgRHvGuzIDdPPHJoqNZU9frK6qR...
# 996  gAAAAABn0yoB4DtxeS5Bvq4wb6FhdYVSiUw4sdLLiX7jwq...
# 997  gAAAAABn0yoBfUpHFr2kkbY-xbwlW6so_hY_tm4TyIbUM5...
# 998  gAAAAABn0yoBHQVGFAqopoDuA8SpuxEC9VdA7fmvxC5TAV...
# 999  gAAAAABn0yoB2_yZHloIc78N9F-qpRuQoxzHCPzoKjB6Qn...
#
#                                     RAM_Size_Encrypted
# 0    gAAAAABn0yoBtNwuhlT6sowq5euqaPHQdJ9S4sgLppWsTT...
# 1    gAAAAABn0yoBf6SIxKvHoyk1JrOwRep7G7R40ZTBsIL3eS...
# 2    gAAAAABn0yoB0S9vjCm3mkAr7rqncUZnpO989e02h1KzED...
# 3    gAAAAABn0yoBpq7cpQ9g8tjSV8nGvg9WAxXgvEPXiL0T5a...
# 4    gAAAAABn0yoBwq71wnacTPYZ_IZnDPhbNqXUvoprNqbO7a...
# ..                                                 ...
# 995  gAAAAABn0yoBCRTqGw-OvhQRMx0OxstolpoE7F8jat3Xmr...
# 996  gAAAAABn0yoBSu3gWkWRPWIOrT091ST9Dyq6zWVDpWLjcL...
# 997  gAAAAABn0yoBtyA_UXGvZauyBMZT9SbSYHS1L1rgA8OkhE...
# 998  gAAAAABn0yoBakdKoSgABBsXTMeVEHdn4KGtyA5TSB5ZSE...
# 999  gAAAAABn0yoBL13NMVPnQnKky0JTGiFldxEeNUdTf978CC...
#
# [1000 rows x 10 columns]

# %%
decrypted_rams = df['RAM_Size_Encrypted'].apply(decrypt_ram).head(5)
print("5 расшифрованных значений RAM:")
print(decrypted_rams)
# Out:
# 5 расшифрованных значений RAM:
# 0    16
# 1     4
# 2     4
# 3    16
# 4    32
# Name: RAM_Size_Encrypted, dtype: object

# %%
# import numpy as np

# # Условные вероятности P(y_j | x_i)
# conditional_probs = np.array([
#     [0.5, 0.25, 0.125, 0.0, 0.0625, 0.0625],
#     [0.0625, 0.25, 0.25, 0.125, 0.0625, 0.25],
#     [0.0625, 0.5, 0.1875, 0.0, 0.125, 0.125],
#     [0.1875, 0.25, 0.125, 0.0625, 0.25, 0.125]
# ])

# # Маргинальные вероятности P(x_i)
# marginal_probs = np.array([0.5, 0.25, 0.125, 0.125])

# # Совместные вероятности P(x_i, y_j)
# joint_probs = conditional_probs * marginal_probs[:, np.newaxis]

# # Элементы, где P(x_i, y_j) > 0
# non_zero_probs = joint_probs[joint_probs > 0]

# # Энтропия объединения
# entropy = -np.sum(non_zero_probs * np.log2(non_zero_probs))
# entropy
# Out:
# np.float64(3.831954882778696)
